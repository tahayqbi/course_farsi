# %% [markdown]
# 1. Load a dictionary of english words into a Python list
# 2. Create a Python dict of anagrams, indexed by anagrammed word
# 3. Challenge: Group dictionary words by their length and then find the total number of anagrams in
# each group
#
#
#
#
#
# part one result >>> ['a', 'aa', 'aal', 'aalir, 'aam'
# 'aani. 'aardvark", 'aardwolf, "aaron', 'aaronic
# 'aaronical', 'aaronite', "aaronitic', ._., ]

# %%
with open('words.txt') as file:
    data = file.readlines()

# %%
data[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
a = data[0]
a
# Out:
# 'A\n'

# %%
a.strip()
# Out:
# 'A'

# %%
data_n = [word[:-1] for word in data]
data_n[:5]
# Out:
# ['A', 'a', 'aa', 'aal', 'aalii']

# %%
data_n_n = [word.lower() for word in data_n]
data_n_n[:5]
# Out:
# ['a', 'a', 'aa', 'aal', 'aalii']

# %%
data_n_n_n = set(data_n_n)
data_n_n_n
# Out:
# {'transylvanian',
#  'peasy',
#  'overfastidiously',
#  'parabolist',
#  'thursday',
#  'auroral',
#  'punti',
#  'tetrahydroxy',
#  'acrostichal',
#  'cloam',
#  'ornithopappi',
#  'watcher',
#  'prosaically',
#  'counterwager',
#  'schizomycosis',
#  'ao',
#  'myxamoeba',
#  'rivulose',
#  'helipterum',
#  'mollycoddle',
#  'turboblower',
#  'processive',
#  'sphenic',
#  'morganatically',
#  'anorthite',
#  'broomwood',
#  'sulphonamido',
#  'forinsec',
#  'heirskip',
#  'bejel',
#  'pyrrhonist',
#  'stenobragmatic',
#  'tubularian',
#  'hydrargyrate',
#  'eclogite',
#  'cloragen',
#  'uncompensated',
#  'quenchlessly',
#  'rostriform',
#  'chemoresistance',
#  'unsurmised',
#  'strident',
#  'underconstable',
#  'python',
#  'mortling',
#  'hyperaphic',
#  'pyrgocephaly',
#  'pean',
#  'perwitsky',
#  'oversensible',
#  'halibiu',
#  'heelpath',
#  'clusterfist',
#  'coronoid',
#  'erechtites',
#  'overcharity',
#  'synchronize',
#  'tikur',
#  'cholangioitis',
#  'troubly',
# ...

# %%
data_n_n_n_n = sorted(data_n_n_n)
data_n_n_n_n[:5]
# Out:
# ['a', 'aa', 'aal', 'aalii', 'aam']

# %%
clean_data = sorted(set([word.strip().lower() for word in data]))
clean_data
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
# ...

# %% [markdown]
# ## task2

# %%
a, b = 'lives', 'elvis'
sorted(a)

sorted(b)
# Out:
# ['e', 'i', 'l', 's', 'v']

# %%
c = sorted(b)

''.join(c)
# Out:
# 'eilsv'

# %%
def signiture(word):
    return ''.join(sorted(word))

# %%
signiture('elvis') == signiture('lives')
# Out:
# True

# %%
signiture('man') == signiture('woman')
# Out:
# False

# %%
[word for word in clean_data if signiture(word) == signiture('dictionary')]
# Out:
# ['dictionary', 'indicatory']
